# %% [markdown]
# # Basket and category
#
# Measure basket breadth, cross-category support/confidence/lift and category decomposition without joining basket metrics to line grain.

# %%
import os
import duckdb

db = os.path.join(os.environ['RETAIL_ARTIFACT_ROOT'], '03_duckdb_and_marts', 'retail_intelligence.duckdb')
connection = duckdb.connect(db, read_only=True)
connection.sql('SELECT * FROM mart_cross_category_pair LIMIT 10')
