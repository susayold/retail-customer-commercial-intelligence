# %% [markdown]
# # Promotion and merchandising
#
# Compare observed panel activity across preserved product-store-week promotion states. Interpret as association only.

# %%
import os
import duckdb

db = os.path.join(os.environ['RETAIL_ARTIFACT_ROOT'], '03_duckdb_and_marts', 'retail_intelligence.duckdb')
connection = duckdb.connect(db, read_only=True)
connection.sql('SELECT * FROM analysis_promotion_association LIMIT 10')
