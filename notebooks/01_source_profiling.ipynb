# %% [markdown]
# # Source profiling
#
# Use only Drive-backed source paths. This notebook records row counts, column names and missingness outputs into Drive QA.

# %%
import os
from pathlib import Path

raw_root = Path(os.environ['RETAIL_DATA_ROOT'])
artifact_root = Path(os.environ['RETAIL_ARTIFACT_ROOT'])
print(raw_root, artifact_root)
