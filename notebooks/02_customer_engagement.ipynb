# %% [markdown]
# # Customer engagement
#
# Explore observed panel spend, active weeks, frequency, basket value and trajectories after the warehouse build.

# %%
import os
import duckdb

db = os.path.join(os.environ['RETAIL_ARTIFACT_ROOT'], '03_duckdb_and_marts', 'retail_intelligence.duckdb')
connection = duckdb.connect(db, read_only=True)
connection.sql('SELECT * FROM mart_customer_segment LIMIT 10')
